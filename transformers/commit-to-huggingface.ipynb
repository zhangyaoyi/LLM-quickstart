# %%
from transformers import AutoModel, AutoTokenizer

model_path = "/home/overman/Workspace/LLM-quickstart/transformers/models/bert-base-cased-finetune-yelp/checkpoint-40000"

# 加载分词器
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

# 加载模型
model = AutoModel.from_pretrained(model_path)

# %%
model.push_to_hub("overman123/bert-base-cased-finetune-yelp")
tokenizer.push_to_hub("overman123/bert-base-cased-finetune-yelp")
# Out:
# README.md:   0%|          | 0.00/240 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/240 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/overman123/bert-base-cased-finetune-yelp/commit/8cbfa9ab6859472d537c3d8d61c7737dbac667f2', commit_message='Upload tokenizer', commit_description='', oid='8cbfa9ab6859472d537c3d8d61c7737dbac667f2', pr_url=None, pr_revision=None, pr_num=None)
